# %% [markdown]
# # heart disease

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

# %%
from numpy import random

# 以下のライブラリを使うので、あらかじめ読み込んでおいてください
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

# 可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# 小数第3位まで表示
# %precision 3
# Out:
# '%.3f'

# %%
# webからデータを取得したり、zipファイルを扱うためのライブラリ
import requests, zipfile
from io import StringIO
import io

# %%
# データがあるfileの指定
file = 'cleveland.data' # heart+diseaseフォルダ

# %%
file
# Out:
# 'cleveland.data'

# %%
import pathlib

read_path = pathlib.Path('/content/drive/MyDrive/Colab Notebooks/cleveland.data')
# write_path = Path('cleveland.csv')

# 読み込み
content = read_path.read_text()

# 置換
content = content.replace(' ', ',')

# 書き出し
# write_path.write_text(content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-877620a9af57> in <cell line: 3>()
#       1 import pathlib
#       2
# ----> 3 read_path = pathlib.Path(b'/content/drive/MyDrive/Colab Notebooks/cleveland.data')
#       4 # write_path = Path('cleveland.csv')
#       5
#
# /usr/lib/python3.10/pathlib.py in __new__(cls, *args, **kwargs)
#     958         if cls is Path:
#     959             cls = WindowsPath if os.name == 'nt' else PosixPath
# --> 960         self = cls._from_parts(args)
#     961         if not self._flavour.is_supported:
#     962             raise NotImplementedError("cannot instantiate %r on your system"
#
# /usr/lib/python3.10/pathlib.py in _from_parts(cls, args)
#     592         # right flavour.
#     593         self = object.__new__(cls)
# --> 594         drv, root, parts = self._parse_args(args)
#     595         self._drv = drv
# ...

# %%
# データをurlから取得する
# r = requests.get(url, stream=True)

# zipfileを読み込み展開する
# z = zipfile.ZipFile(io.BytesIO(r.content))
# z.extractall()

heartdisease_data_math = pd.read_csv(file)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-15-caa471af3c0c> in <cell line: 8>()
#       6 # z.extractall()
#       7
# ----> 8 heartdisease_data_math = pd.read_csv(file)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
# 入力ファイルと出力ファイルのパスを指定
"""
input_file_path = "cleveland.data"
output_file_path = "cleveland.csv"

try:
    # 入力ファイルを開いてテキストを読み取る
    with open(input_file_path, 'r') as input_file:
        input_text = input_file.read()

    # データ変換を行う（ここでは大文字に変換する例）
    converted_text = input_text.upper()

    # 出力ファイルを開いて変換されたデータを書き込む
    with open(output_file_path, 'w') as output_file:
        output_file.write(converted_text)

    print("ファイルの変換が完了しました。")
except Exception as e:
    print(f"エラーが発生しました: {str(e)}")

# %%
input_file_path = "cleveland.data"
output_file_path = "cleveland.csv"

# 入力ファイルを開いてテキストを読み取る
with open(input_file_path, 'rb') as input_file:
    input_text = input_file.read()
print(input_text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-ab3b8c7971d9> in <cell line: 5>()
#       3
#       4 # 入力ファイルを開いてテキストを読み取る
# ----> 5 with open(input_file_path, 'rb') as input_file:
#       6     input_text = input_file.read()
#       7 print(input_text)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cleveland.data'

# %%
l_part1 = []
l_part = input_text.split(b" ")
print(l_part)
# Out:
# [b'1', b'0', b'63', b'1', b'-9', b'-9', b'-9\n-9', b'1', b'145', b'1', b'233', b'-9', b'50', b'20\n1', b'-9', b'1', b'2', b'2', b'3', b'81', b'0\n0', b'0', b'0', b'0', b'1', b'10.5', b'6', b'13\n150', b'60', b'190', b'90', b'145', b'85', b'0', b'0\n2.3', b'3', b'-9', b'172', b'0', b'-9', b'-9', b'-9\n-9', b'-9', b'-9', b'6', b'-9', b'-9', b'-9', b'2\n16', b'81', b'0', b'1', b'1', b'1', b'-9', b'1\n-9', b'1', b'-9', b'1', b'1', b'1', b'1', b'1\n1', b'1', b'-9', b'-9', b'name\n2', b'0', b'67', b'1', b'-9', b'-9', b'-9\n-9', b'4', b'160', b'1', b'286', b'-9', b'40', b'40\n0', b'-9', b'1', b'2', b'3', b'5', b'81', b'0\n1', b'0', b'0', b'0', b'1', b'9.5', b'6', b'13\n108', b'64', b'160', b'90', b'160', b'90', b'1', b'0\n1.5', b'2', b'-9', b'185', b'3', b'-9', b'-9', b'-9\n-9', b'-9', b'-9', b'3', b'-9', b'-9', b'-9', b'2\n5', b'81', b'2', b'1', b'2', b'2', b'-9', b'2\n-9', b'1', b'-9', b'1', b'1', b'1', b'1', b'1\n1', b'1', b'-9', b'-9', b'name\n3', b'0', b'67', b'1', b'-9', b'-9', b'-9\n
# ...

# %%
str1 = b''
for i in range(len(l_part)):
    if i == len(l_part)-1:
      str1 += l_part[i]
    else:
      str1 += l_part[i]+b','

# l_part1 = l_part

# %%
print(str1)
# Out:
# b'1,0,63,1,-9,-9,-9\n-9,1,145,1,233,-9,50,20\n1,-9,1,2,2,3,81,0\n0,0,0,0,1,10.5,6,13\n150,60,190,90,145,85,0,0\n2.3,3,-9,172,0,-9,-9,-9\n-9,-9,-9,6,-9,-9,-9,2\n16,81,0,1,1,1,-9,1\n-9,1,-9,1,1,1,1,1\n1,1,-9,-9,name\n2,0,67,1,-9,-9,-9\n-9,4,160,1,286,-9,40,40\n0,-9,1,2,3,5,81,0\n1,0,0,0,1,9.5,6,13\n108,64,160,90,160,90,1,0\n1.5,2,-9,185,3,-9,-9,-9\n-9,-9,-9,3,-9,-9,-9,2\n5,81,2,1,2,2,-9,2\n-9,1,-9,1,1,1,1,1\n1,1,-9,-9,name\n3,0,67,1,-9,-9,-9\n-9,4,120,1,229,-9,20,35\n0,-9,1,2,2,19,81,0\n1,0,0,0,1,8.5,6,10\n129,78,140,80,120,80,1,0\n2.6,2,-9,150,2,-9,-9,-9\n-9,-9,-9,7,-9,-9,-9,2\n20,81,1,1,1,1,-9,1\n-9,1,-9,2,2,1,1,1\n7,3,-9,-9,name\n4,0,37,1,-9,-9,-9\n-9,3,130,0,250,-9,0,0\n0,-9,1,0,2,13,81,0\n1,0,0,0,1,13,13,17\n187,84,195,68,130,78,0,0\n3.5,3,-9,167,0,-9,-9,-9\n-9,-9,-9,3,-9,-9,-9,2\n4,81,0,1,1,1,-9,1\n-9,1,-9,1,1,1,1,1\n1,1,-9,-9,name\n6,0,41,0,-9,-9,-9\n-9,2,130,1,204,-9,0,0\n0,-9,1,2,2,7,81,0\n0,0,0,0,1,7,-9,9\n172,71,160,74,130,86,0,0\n1.4,1,-9,40,0,-9,-9,-9\n-9,-9,-9,3,-9,-9,-9,
# ...

# %%
with open(output_file_path, 'w') as output_file:
  output_file.write(string(str1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-18584497f1ad> in <cell line: 1>()
#       1 with open(output_file_path, 'w') as output_file:
# ----> 2   output_file.write(string(str1))
#
# NameError: name 'string' is not defined

# %%
print(l_part1)
# Out:
# []

# %%
read_path = pathlib.Path('/content/drive/MyDrive/Colab Notebooks/cleveland.csv')
content = read_path.read_text()
content
# Out:
# 'id,ccf,age,sex,painloc,painexer,relrest,pncaden,cp,trestbps,htn,chol,smoke,cigs,years,fbs,dm,famhist,restecg,ekgmo,ekgday,ekgyr,dig,prop,nitr,pro,diuretic,proto,thaldur,thaltime,met,thalach,thalrest,tpeakbps,tpakbpd,dummy,trestbpd,exang,xhypo,oldpeak,slope,rldv5,rldv5e,ca,reatckm,exerckm,restef,restwm,exeref,exerwm,thal,thalsev,thalpul,earlobe,cmo,cday,cyr,num,lmt,ladprox,laddist,diag,cxmain,ramus,om1,om2,rcaprox,rcadist,lvx1,lvx2,lvx3,lvx4,lvf,cathef,junk,name\n1,0,63,1,-9,-9,-9,-9,1,145,1,233,-9,50,20,1,-9,1,2,2,3,81,0,0,0,0,0,1,10.5,6,13,150,60,190,90,145,85,0,0,2.3,3,-9,172,0,-9,-9,-9,-9,-9,-9,6,-9,-9,-9,2,16,81,0,1,1,1,-9,1,-9,1,-9,1,1,1,1,1,1,1,-9,-9,name\n2,0,67,1,-9,-9,-9,-9,4,160,1,286,-9,40,40,0,-9,1,2,3,5,81,0,1,0,0,0,1,9.5,6,13,108,64,160,90,160,90,1,0,1.5,2,-9,185,3,-9,-9,-9,-9,-9,-9,3,-9,-9,-9,2,5,81,2,1,2,2,-9,2,-9,1,-9,1,1,1,1,1,1,1,-9,-9,name\n3,0,67,1,-9,-9,-9,-9,4,120,1,229,-9,20,35,0,-9,1,2,2,19,81,0,1,0,0,0,1,8.5,6,10,129,78,140,80,120,80,1,0,2.6,2,-9,150,2,-9,-
# ...

# %%
heartdisease_cleveland_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/cleveland.csv')

# %%
heartdisease_cleveland_data
# Out:
#       id  ccf  age  sex  painloc  painexer  relrest  pncaden  cp  trestbps  \
# 0      1    0   63    1       -9        -9       -9       -9   1       145
# 1      2    0   67    1       -9        -9       -9       -9   4       160
# 2      3    0   67    1       -9        -9       -9       -9   4       120
# 3      4    0   37    1       -9        -9       -9       -9   3       130
# 4      6    0   41    0       -9        -9       -9       -9   2       130
# ..   ...  ...  ...  ...      ...       ...      ...      ...  ..       ...
# 277  294    0   39    0       -9        -9       -9       -9   3       138
# 278  295    0   57    1       -9        -9       -9       -9   2       154
# 279  296    0   58    0       -9        -9       -9       -9   4       130
# 280  297    0   57    1       -9        -9       -9       -9   4       110
# 281  298    0   47    1       -9        -9       -9       -9   3       130
#
# ...

# %%
my_string = "こんにちは、世界！"
my_bytes = my_string.encode('utf-8')

print(my_bytes)
# Out:
# b'\xe3\x81\x93\xe3\x82\x93\xe3\x81\xab\xe3\x81\xa1\xe3\x81\xaf\xe3\x80\x81\xe4\xb8\x96\xe7\x95\x8c\xef\xbc\x81'

# %%
my_bytes_e = my_bytes.decode('utf-8')

print(my_bytes_e)
# Out:
# こんにちは、世界！

# %%
print(my_string)
# Out:
# こんにちは、世界！

# %% [markdown]
# # rice 20231003

# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
rice_cammeo_and_osmancik = fetch_ucirepo(id=545)

# data (as pandas dataframes)
rice = rice_cammeo_and_osmancik.data.features
y = rice_cammeo_and_osmancik.data.targets

# metadata
print(rice_cammeo_and_osmancik.metadata)

# variable information
print(rice_cammeo_and_osmancik.variables)
# Out:
# {'uci_id': 545, 'name': 'Rice (Cammeo and Osmancik)', 'repository_url': 'https://archive.ics.uci.edu/dataset/545/rice+cammeo+and+osmancik', 'data_url': 'https://archive.ics.uci.edu/static/public/545/data.csv', 'abstract': "A total of 3810 rice grain's images were taken for the two species, processed and feature inferences were made. 7 morphological features were obtained for each grain of rice.", 'area': 'Computer Science', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 3810, 'num_features': 7, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['Class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2019, 'last_updated': 'Fri Aug 18 2023', 'dataset_doi': '10.24432/C5MW4Z', 'creators': [], 'intro_paper': {'title': 'Classification of Rice Varieties Using Artificial Intelligence Methods', 'authors': 'Ilkay Cinar, M. Koklu', 'published_in': 'International Journal of Intelligent Syst
# ...

# %%
rice_cammeo_and_osmancik
# Out:
# {'data': {'ids': None,
#   'features':        Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
#   0     15231  525.578979         229.749878          85.093788      0.928882
#   1     14656  494.311005         206.020065          91.730972      0.895405
#   2     14634  501.122009         214.106781          87.768288      0.912118
#   3     13176  458.342987         193.337387          87.448395      0.891861
#   4     14688  507.166992         211.743378          89.312454      0.906691
#   ...     ...         ...                ...                ...           ...
#   3805  11441  415.858002         170.486771          85.756592      0.864280
#   3806  11625  421.390015         167.714798          89.462570      0.845850
#   3807  12437  442.498993         183.572922          86.801979      0.881144
#   3808   9882  392.296997         161.193985          78.210480      0.874406
#   3809  11434  404.709992         161.079269          90.868195      0.825692
# ...

# %%
print(rice)
# Out:
#        Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0     15231  525.578979         229.749878          85.093788      0.928882
# 1     14656  494.311005         206.020065          91.730972      0.895405
# 2     14634  501.122009         214.106781          87.768288      0.912118
# 3     13176  458.342987         193.337387          87.448395      0.891861
# 4     14688  507.166992         211.743378          89.312454      0.906691
# ...     ...         ...                ...                ...           ...
# 3805  11441  415.858002         170.486771          85.756592      0.864280
# 3806  11625  421.390015         167.714798          89.462570      0.845850
# 3807  12437  442.498993         183.572922          86.801979      0.881144
# 3808   9882  392.296997         161.193985          78.210480      0.874406
# 3809  11434  404.709992         161.079269          90.868195      0.825692
#
#       Convex_Area    Extent
# ...

# %%
print(y)
# Out:
#          Class
# 0       Cammeo
# 1       Cammeo
# 2       Cammeo
# 3       Cammeo
# 4       Cammeo
# ...        ...
# 3805  Osmancik
# 3806  Osmancik
# 3807  Osmancik
# 3808  Osmancik
# 3809  Osmancik
#
# [3810 rows x 1 columns]

# %%
print(rice['Area'])
# Out:
# 0       15231
# 1       14656
# 2       14634
# 3       13176
# 4       14688
#         ...
# 3805    11441
# 3806    11625
# 3807    12437
# 3808     9882
# 3809    11434
# Name: Area, Length: 3810, dtype: int64

# %%
print(rice.head())
# Out:
#     Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0  15231  525.578979         229.749878          85.093788      0.928882
# 1  14656  494.311005         206.020065          91.730972      0.895405
# 2  14634  501.122009         214.106781          87.768288      0.912118
# 3  13176  458.342987         193.337387          87.448395      0.891861
# 4  14688  507.166992         211.743378          89.312454      0.906691
#
#    Convex_Area    Extent
# 0        15617  0.572896
# 1        15072  0.615436
# 2        14954  0.693259
# 3        13368  0.640669
# 4        15262  0.646024

# %%
rice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3810 entries, 0 to 3809
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Area               3810 non-null   int64
#  1   Perimeter          3810 non-null   float64
#  2   Major_Axis_Length  3810 non-null   float64
#  3   Minor_Axis_Length  3810 non-null   float64
#  4   Eccentricity       3810 non-null   float64
#  5   Convex_Area        3810 non-null   int64
#  6   Extent             3810 non-null   float64
# dtypes: float64(5), int64(2)
# memory usage: 208.5 KB

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(rice['Perimeter'])
plt.xlabel('Area')
plt.ylabel('Perimeter')
plt.grid(True)

# %%
plt.hist(rice['Major_Axis_Length'])
plt.xlabel('Area')
plt.ylabel('Major_Axis_Length')
plt.grid(True)

# %%
# 平均値
print('平均値：', rice['Perimeter'].mean())
# 中央値：中央値でデータを分けると中央値の前後でデータ数が同じになる（データの真ん中の値）、外れ値の値に影響を受けにくい
print('中央値：', rice['Perimeter'].median())
# 最頻値：最も頻度が多い値
print('最頻値：', rice['Perimeter'].mode())
# Out:
# 平均値： 454.23918014839893
# 中央値： 448.85249325
# 最頻値： 0    432.298004
# Name: Perimeter, dtype: float64

# %%
import numpy as np

# %%
# 以下のライブラリを使うので、あらかじめ読み込んでおいてください
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

# 可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# 小数第3位まで表示
# %precision 3
# Out:
# '%.3f'

# %%
# 現在の値を表示
print('そのまま：', rice)

# ソートした結果を表示
# data = X.sort()
# print('ソート後：', data)
# Out:
# そのまま：        Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0     15231  525.578979         229.749878          85.093788      0.928882
# 1     14656  494.311005         206.020065          91.730972      0.895405
# 2     14634  501.122009         214.106781          87.768288      0.912118
# 3     13176  458.342987         193.337387          87.448395      0.891861
# 4     14688  507.166992         211.743378          89.312454      0.906691
# ...     ...         ...                ...                ...           ...
# 3805  11441  415.858002         170.486771          85.756592      0.864280
# 3806  11625  421.390015         167.714798          89.462570      0.845850
# 3807  12437  442.498993         183.572922          86.801979      0.881144
# 3808   9882  392.296997         161.193985          78.210480      0.874406
# 3809  11434  404.709992         161.079269          90.868195      0.825692
#
#       Convex_Area    Extent
# ...

# %%
# 分散
rice['Perimeter'].var()
# Out:
# 1267.1522072029484

# %%
rice['Perimeter'].std()
# Out:
# 35.59708144220462

# %%
np.sqrt(rice['Perimeter'].var())
# Out:
# 35.59708144220462

# %%
# 要約統計量
rice['Perimeter'].describe()
# Out:
# count    3810.000000
# mean      454.239180
# std        35.597081
# min       359.100006
# 25%       426.144752
# 50%       448.852493
# 75%       483.683746
# max       548.445984
# Name: Perimeter, dtype: float64

# %% [markdown]
# #### 四方位範囲を求める
#
# `describe`メソッドの結果は、`Series`オブジェクトに入ります。
#
#
# それぞれの要素は、`describe()[インデックス番号]`として取得できます。たとえば、平均値を示す`mean`の値は、`describe()[1]`、標準偏差を示す`std`の値は`describe()[2]`です

# %%
# 四分位範囲(75%タイル ー 25%タイル)
rice['Perimeter'].describe()[6] - rice['Perimeter'].describe()[4]
# Out:
# 57.53899387500002

# %%
# 箱ひげ図：G1,G2,G3
plt.boxplot([rice['Major_Axis_Length'], rice['Minor_Axis_Length']])
plt.grid(True)

# %%
# 変動係数：長軸の長さ
rice['Major_Axis_Length'].std() / rice['Major_Axis_Length'].mean()
# Out:
# 0.09243048895875035

# %%
# 変動係数：短軸の長さ
rice['Minor_Axis_Length'].std() / rice['Minor_Axis_Length'].mean()
# Out:
# 0.06638359831468583

# %%
# それぞれの変動係数をまとめて計算
rice.std() / rice.mean()
# Out:
# Area                 0.136754
# Perimeter            0.078366
# Major_Axis_Length    0.092430
# Minor_Axis_Length    0.066384
# Eccentricity         0.023473
# Convex_Area          0.137191
# Extent               0.116687
# dtype: float64

# %%
# 散布図
plt.plot(rice['Major_Axis_Length'], rice['Minor_Axis_Length'], 'o')# 長軸の長さと短軸の長さ

# ラベル
plt.ylabel('Major_Axis_Length')
plt.xlabel('Minor_Axis_Length')
plt.grid(True)

# %% [markdown]
# #### 共分散

# %%
# 共分散行列
np.cov(rice['Major_Axis_Length'], rice['Minor_Axis_Length'])
# Out:
# array([[304.456,  45.199],
#        [ 45.199,  32.831]])

# %% [markdown]
# 結果の行列の意味は、次の通りです。
#
# Major_Axis_LengthとMinor_Axis_Lengthの共分散 … 共分散行列の (1,2)
#  と (2,1)
#  の要素です。
#
# Major_Axis_Lengthの分散 … 共分散行列の (1,1)
#  の要素です。
#
# Minor_Axis_Lengthの分散 … 共分散行列の (2,2)
#  の要素です。
# それぞれMajor_Axis_LengthとMinor_Axis_Lengthの分散は、var関数で計算。実際に求めてみると、値が合致する。

# %%
# 分散
print('Major_Axis_Lengthの分散:',rice['Major_Axis_Length'].var())
print('Minor_Axis_Lengthの分散:',rice['Minor_Axis_Length'].var())
# Out:
# Major_Axis_Lengthの分散: 304.45638143520824
# Minor_Axis_Lengthの分散: 32.83080667759282

# %% [markdown]
# 相関係数

# %% [markdown]
# \begin{eqnarray}
# r_{xy} = \frac{\displaystyle \sum_{i = 1}^n (x_i - \overline{x})
# (y_i - \overline{y})}{\sqrt{\displaystyle \sum_{i = 1}^n
# (x_i - \overline{x})^2}\sqrt{\displaystyle \sum_{i = 1}^n
# (y_i - \overline{y})^2}}
# \end{eqnarray}

# %% [markdown]
# この相関係数は、-1から1までの値を取り、1に近ければ近いほど**正の相関**があるといい、-1に近ければ近いほど**負の相関**があるといいます。0に近い場合は、**無相関**であるといいます。

# %% [markdown]
# Pythonでは、ピアソン関数が計算できるScipyの`pearsonr`を使って、2変数の相関係数を算出できます。
#
# データ分析では 相関関数=ピアソン関数

# %%
sp.stats.pearsonr(rice['Major_Axis_Length'], rice['Minor_Axis_Length'])
# Out:
# PearsonRResult(statistic=0.4520920951971871, pvalue=2.465940212981037e-191)

# %% [markdown]
# この相関係数は、-1から1までの値を取り、1に近ければ近いほど**正の相関**があるといい、-1に近ければ近いほど**負の相関**があるといいます。0に近い場合は、**無相関**であるといいます。

# %%
# 相関行列
np.corrcoef([rice['Major_Axis_Length'], rice['Minor_Axis_Length']])
# Out:
# array([[1.   , 0.452],
#        [0.452, 1.   ]])

# %%
import seaborn as sn

# %%
sn.pairplot(rice[['Area', 'Perimeter', 'Major_Axis_Length', 'Minor_Axis_Length']])
plt.grid(True)

# %%
# 例：面積ごとの長軸の平均値
rice.groupby('Area')['Major_Axis_Length'].mean()
# Out:
# Area
# 7551     163.408829
# 7833     162.516434
# 7943     154.886322
# 8328     152.565857
# 8499     156.072281
#             ...
# 17564    221.602936
# 17856    223.292358
# 17948    214.093826
# 18313    222.464249
# 18913    227.135483
# Name: Major_Axis_Length, Length: 2828, dtype: float64

# %%
rice.groupby(rice['Area']==8499)['Major_Axis_Length'].mean()
# Out:
# Area
# False    188.784808
# True     156.072281
# Name: Major_Axis_Length, dtype: float64

# %%
rice_cammeo_and_osmancik
# Out:
# {'data': {'ids': None,
#   'features':        Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
#   0     15231  525.578979         229.749878          85.093788      0.928882
#   1     14656  494.311005         206.020065          91.730972      0.895405
#   2     14634  501.122009         214.106781          87.768288      0.912118
#   3     13176  458.342987         193.337387          87.448395      0.891861
#   4     14688  507.166992         211.743378          89.312454      0.906691
#   ...     ...         ...                ...                ...           ...
#   3805  11441  415.858002         170.486771          85.756592      0.864280
#   3806  11625  421.390015         167.714798          89.462570      0.845850
#   3807  12437  442.498993         183.572922          86.801979      0.881144
#   3808   9882  392.296997         161.193985          78.210480      0.874406
#   3809  11434  404.709992         161.079269          90.868195      0.825692
# ...

# %%
y
# Out:
#          Class
# 0       Cammeo
# 1       Cammeo
# 2       Cammeo
# 3       Cammeo
# 4       Cammeo
# ...        ...
# 3805  Osmancik
# 3806  Osmancik
# 3807  Osmancik
# 3808  Osmancik
# 3809  Osmancik
#
# [3810 rows x 1 columns]

# %%
# 例：面積ごとの長軸の平均値
rice.groupby(y['Class']=='Cammeo')['Major_Axis_Length'].mean()
# Out:
# Class
# False    176.287755
# True     205.478589
# Name: Major_Axis_Length, dtype: float64

# %%
print('そのまま：', rice)
# Out:
# そのまま：        Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0     15231  525.578979         229.749878          85.093788      0.928882
# 1     14656  494.311005         206.020065          91.730972      0.895405
# 2     14634  501.122009         214.106781          87.768288      0.912118
# 3     13176  458.342987         193.337387          87.448395      0.891861
# 4     14688  507.166992         211.743378          89.312454      0.906691
# ...     ...         ...                ...                ...           ...
# 3805  11441  415.858002         170.486771          85.756592      0.864280
# 3806  11625  421.390015         167.714798          89.462570      0.845850
# 3807  12437  442.498993         183.572922          86.801979      0.881144
# 3808   9882  392.296997         161.193985          78.210480      0.874406
# 3809  11434  404.709992         161.079269          90.868195      0.825692
#
#       Convex_Area    Extent
# ...

# %% [markdown]
# #### 練習問題

# %% [markdown]
# #### 3.4単回帰分析

# %%
# 散布図
plt.plot(rice['Major_Axis_Length'], rice['Minor_Axis_Length'], 'o')
plt.xlabel('長軸の長さ')
plt.ylabel('短軸の長さ')
plt.grid(True)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 38263 (\N{CJK UNIFIED IDEOGRAPH-9577}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 36600 (\N{CJK UNIFIED IDEOGRAPH-8EF8}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 12373 (\N{HIRAGANA LETTER SA}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 30701 (\N{CJK UNIFIED IDEOGRAPH-77ED}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
from sklearn import linear_model

# 線形回帰のインスタンスを生成
reg = linear_model.LinearRegression()

# %% [markdown]
# 以下では、説明変数（$X$とします）と目的変数（$Y$とします）データをセットして、線形回帰する`fit`という機能を使って、予測モデルを計算します。
#
# この場合の`fit`関数は、**最小二乗法**という手法で回帰係数$a$と切片$b$を計算しています。この方法は、実際の目的変数のデータと予測したデータの差の二乗和をとり、それが最小になる時の係数と切片を求めるものです。式で表現すると、$y$を実測値、$ f(x) = ax + b $を予測値として、以下の式を最小にするように計算しています（計算方法としては、この式を微分していくのですが、`fit`関数を実行すれば、その計算をしてくれるので詳細は割愛します）。

# %% [markdown]
# \begin{eqnarray}
# \sum^n_{i=1}(y_i-f(x_i))^2
# \end{eqnarray}

# %%
# 説明変数に "長軸の長さ" を利用
# locはデータフレームから、行と列を指定して取り出す。loc[:, ['G1']]は、G1列のすべての列を取り出すことをしている
# valuesに直しているので、注意
X = rice.loc[:, ['Major_Axis_Length']].values

# 目的変数に "短軸の長さ" を利用
Y = rice['Minor_Axis_Length'].values

# 予測モデルを計算、ここでa,bを算出
reg.fit(X, Y)

# 回帰係数
print('回帰係数:', reg.coef_)

# 切片
print('切片:', reg.intercept_)
# Out:
# 回帰係数: [0.148]
# 切片: 58.288310360707484

# %% [markdown]
# 上記の回帰係数が線形の回帰式 $ y = ax + b $ における$ a $に相当し、切片に相当するのが$b$です。先ほどの散布図と重ねて、予測した線形回帰式を描いてみましょう。$Y$、つまり予測したい最終の数学の成績G3は、`predict`を使って、括弧の中に説明変数を入れることで計算できます。

# %%
# 先ほどと同じ散布図
plt.scatter(X, Y)
plt.xlabel('長軸の長さ')
plt.ylabel('短軸の長さ')

# その上に線形回帰直線を引く
plt.plot(X, reg.predict(X))
plt.grid(True)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 38263 (\N{CJK UNIFIED IDEOGRAPH-9577}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 36600 (\N{CJK UNIFIED IDEOGRAPH-8EF8}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 12373 (\N{HIRAGANA LETTER SA}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 30701 (\N{CJK UNIFIED IDEOGRAPH-77ED}) missing from current font.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# ### 3.4.2 決定係数
#
# 上記のグラフ + 客観的にどうなのかを数値化したものが、**決定係数**
# 決定係数は寄与率とも呼ばれます。定義は以下のとおりです。決定係数は$R^2$と示すことが一般的です。

# %% [markdown]
# \begin{eqnarray}
# R^2 = 1 - \frac{\sum_{i = 1}^n(y_i - f(x_i))^2}{\sum_{i = 1}^{n}(y_i - \bar{y})^2}
# \end{eqnarray}

# %% [markdown]
# $R^2$は最大で1の値を取り、1に近ければ近いほど良いモデルになります。$\bar{y}$は目的変数の平均値です。説明変数を使わずに常に$\bar{y}$（定数）で予測した場合と二乗誤差が等しい場合に $R^2=0$ となります。Pythonを使って決定係数を求めるには、`score`を使って以下のようにします。

# %%
# 決定係数、寄与率とも呼ばれる
print('決定係数:', reg.score(X, Y))
# Out:
# 決定係数: 0.20438726253978257

# %% [markdown]
# ### ■総合問題3-2 ローレンツ曲線とジニ係数
#
# この章で利用したサンプルデータstudent_data_mathのデータを使って、以下の問いに答えてください。ここで扱うローレンツ曲線やジニ係数は、貧富の格差（地域別、国別など）を見るための指標として使われています（なお、本問題は少し難易度が高いため、参考程度に見てください。詳細は、以前に紹介した統計学入門などの文献を参照するか、ネットで検索してください）。
#
# （1）一期目の数学データについて、男女別に昇順に並び替えをしてください。そして、横軸に人数の累積比率、縦軸に一期目の値の累積比率をとってください。この曲線をローレンツ曲線といいます。このローレンツ曲線を男女別に一期目の数学成績でグラフ化してください。
#
# （2）不平等の程度を数値で表したものをジニ係数といいます。この値は、ローレンツ曲線と45度線で囲まれた部分の面積の2倍で定義されて、0から1の値を取ります。値が大きければ大きいほど、不平等の度合いが大きくなります。なお以下のようにジニ係数は定義できます。$\overline{x}$は平均値です。
#
# \begin{eqnarray}
# GI=\sum_{i}\sum_{j}\left| \frac{x_i-x_j}{2n^2 \overline{x}}\right|
# \end{eqnarray}
#
# これを利用して、男女の一期目の成績について、ジニ係数をそれぞれ求めてください。

# %% [markdown]
# # SEIR 2023/10/03 SEIR_01_1000_100_80_05_01_30_100_5_700step.csv

# %% [markdown]
# ## インポート失敗

# %%
from pathlib import Path

read_path = Path('SEIR_01_1000_100_80_05_01_30_100_5_700step.csv')

# 読み込み
content = read_path.read_text()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-89-ae0319f43c30> in <cell line: 6>()
#       4
#       5 # 読み込み
# ----> 6 content = read_path.read_text()
#
# /usr/lib/python3.10/pathlib.py in read_text(self, encoding, errors)
#    1133         encoding = io.text_encoding(encoding)
#    1134         with self.open(mode='r', encoding=encoding, errors=errors) as f:
# -> 1135             return f.read()
#    1136
#    1137     def write_bytes(self, data):
#
# /usr/lib/python3.10/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# ...

# %%
content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-7fe70820e08a> in <cell line: 1>()
# ----> 1 content
#
# NameError: name 'content' is not defined

# %% [markdown]
# ## インポートその2

# %%
import pathlib

# %%
import csv

filename = 'SEIR_01_1000_100_80_05_01_30_100_5_700step.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)
    for row in csvreader:
        print(row)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-22-d1935d000a16> in <cell line: 4>()
#       4 with open(filename, encoding='utf8', newline='') as f:
#       5     csvreader = csv.reader(f)
# ----> 6     for row in csvreader:
#       7         print(row)
#
# /usr/lib/python3.10/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 19-20: invalid continuation byte

# %% [markdown]
# ## インポートその3

# %%
import csv

with open('/content/drive/MyDrive/Colab Notebooks/SEIR_01_1000_100_80_05_01_30_100_5_700step.csv', 'r') as f:
    reader = csv.reader(f)
    for line in reader:
        print(line)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-14-fbf0c3c6b7ce> in <cell line: 3>()
#       3 with open('/content/drive/MyDrive/Colab Notebooks/SEIR_01_1000_100_80_05_01_30_100_5_700step.csv', 'rb') as f:
#       4     reader = csv.reader(f)
# ----> 5     for line in reader:
#       6         print(line)
#
# Error: iterator should return strings, not bytes (the file should be opened in text mode)

# %%
filename
# Out:
# 'SEIR_01_1000_100_80_05_01_30_100_5_700step.csv'

# %% [markdown]
# #### ファイルインポート

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

data_list = []
# CSVファイルを読み取る
with open('/content/drive/MyDrive/Colab Notebooks/SEIR_01_1000_100_80_05_01_30_100_5_700step.csv', 'r', encoding='iso-8859-1') as file:
  for line in file:
        # 各行をカンマで分割し、リストに格納
        data = line.split(',')
        print(data)
        data_list.append(data)

# データフレーム（df）にCSVデータが読み込まれます
# Out:
# ['"å\x81¥å¸¸è\x80\x85ï¼\x88æ\x84\x9få\x8f\x97æ§è\x80\x85ï¼\x89ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå¤§å\x80¤', 'æ\x84\x9fæ\x9f\x93è\x80\x85ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå¤§å\x80¤', 'å\x85\x8dç\x96«ä¿\x9dæ\x8c\x81è\x80\x85ï¼\x88é\x99¤å¤\x96è\x85ï¼\x89ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå¤§å\x80¤', 'æ½\x9cä¼\x8fæ\x84\x9fæ\x9f\x93è\x85ï¼\x88æ½\x9cä¼\x8fæ\x84\x9få\x8f\x97æ§è\x80\x85ï¼\x89ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå¤§å\x80¤', '(å®\x9fè¡\x8cã\x81\x8cå§\x8bã\x81¾ã\x81£ã\x81¦ã\x81\x8bã\x82\x89)å\x81¥å¸¸è\x80\x85ï¼\x88æ\x84\x9få\x8f\x97æ§è\x80\x85ï¼\x89ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå°\x8få¤', 'æ\x84\x9fæ\x9f\x93è\x80\x85ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå°\x8få¤', 'å\x85\x8dç\x96«ä¿\x9dæ\x8c\x81è\x80\x85ï¼\x88é\x99¤å¤\x96è\x85ï¼\x89ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå°\x8få¤', 'æ½\x9cä¼\x8fæ\x84\x9fæ\x9f\x93è\x85ï¼\x88æ½\x9cä¼\x8fæ\x84\x9få\x8f\x97æ§è\x80\x85ï¼\x89ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå°\x8få¤', 'class"\n']
# ['"1', '0.065', '0.013', '0.014', '0.925', '0', '0', '0', 'SEIR_01_1000_100_80_05_01_30_100_5_700step"\n']
# ...

# %%
ls
# Out:
# drive/  sample_data/

# %%
pwd
# Out:
# '/content'

# %%
data_list
# Out:
# [['"å\x81¥å¸¸è\x80\x85ï¼\x88æ\x84\x9få\x8f\x97æ§è\x80\x85ï¼\x89ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå¤§å\x80¤',
#   'æ\x84\x9fæ\x9f\x93è\x80\x85ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå¤§å\x80¤',
#   'å\x85\x8dç\x96«ä¿\x9dæ\x8c\x81è\x80\x85ï¼\x88é\x99¤å¤\x96è\x85ï¼\x89ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå¤§å\x80¤',
#   'æ½\x9cä¼\x8fæ\x84\x9fæ\x9f\x93è\x85ï¼\x88æ½\x9cä¼\x8fæ\x84\x9få\x8f\x97æ§è\x80\x85ï¼\x89ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå¤§å\x80¤',
#   '(å®\x9fè¡\x8cã\x81\x8cå§\x8bã\x81¾ã\x81£ã\x81¦ã\x81\x8bã\x82\x89)å\x81¥å¸¸è\x80\x85ï¼\x88æ\x84\x9få\x8f\x97æ§è\x80\x85ï¼\x89ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå°\x8få¤',
#   'æ\x84\x9fæ\x9f\x93è\x80\x85ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå°\x8få¤',
#   'å\x85\x8dç\x96«ä¿\x9dæ\x8c\x81è\x80\x85ï¼\x88é\x99¤å¤\x96è\x85ï¼\x89ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå°\x8få¤',
#   'æ½\x9cä¼\x8fæ\x84\x9fæ\x9f\x93è\x85ï¼\x88æ½\x9cä¼\x8fæ\x84\x9få\x8f\x97æ§è\x80\x85ï¼\x89ã®æ¯\x94ç\x8e\x87ã\x81®æ\x9cå°\x8få¤',
#   'class"\n'],
#  ['"1',
#   '0.065',
#   '0.013',
#   '0.014',
#   '0.925',
#   '0',
# ...

# %%
data
# Out:
# ['"0.986',
#  '0.186',
#  '0.11',
#  '0.133',
#  '0.596',
#  '0.186',
#  '0.11',
#  '0.133',
#  'SEIR_01_1000_100_10_04_042_30_100_5_700step"']

# %%
cd drive
# Out:
# /content/drive

# %%
ls
# Out:
# MyDrive/

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
# 'Colab Notebooks'/
#  IMG_0652.png
# '【LTCL】入学後手引_v004  .pdf'
#  MBTIについてlancers経由（回答）.gsheet
# 'アイデア紹介のプレゼンテーション（提供: Made To Stick）.gslides'
#  イベント出欠確認.gform
# 'プロトタイピング プレゼンテーション.gslides'
# '【レバテックカレッジ】目標シート（入学ガイダンス用） (1).xlsx'
# '※原本コピーして使用【2022年11月1日入学】受講生スケジュール目標 .gsheet'
# '無題のドキュメント (1).gdoc'
#  無題のドキュメント.gdoc
# '無題のフォーム (1).gform'
#  無題のフォーム.gform
#  無題のプレゼンテーション.gslides
# '【雛形】47インターンシップES_フォーマット(コピーして使ってね) のコピー.gdoc'

# %%
cd 'Colab Notebooks'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
ls
# Out:
# cleveland.csv
# cleveland.data
# heart+disease.ipynb
# hungry.ipynb
# rice_and_SEIRmodel.ipynb
# SEIR_01_1000_100_80_0.5_0.1_30_100_5_700step.csv
# SEIR_01_3000_100_10_1_01_30_100_5_700step.csv
# Untitled
# Untitled0.ipynb
# Untitled1.ipynb
# Untitled3.ipynb

# %%
csv_file = open('/content/drive/MyDrive/Colab Notebooks/SEIR_01_1000_100_80_05_01_30_100_5_700step.csv', 'r')

column_list = csv_file.readline().rstrip().split(',')

print(column_list)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-40c08d54c8ca> in <cell line: 3>()
#       1 csv_file = open('/content/drive/MyDrive/Colab Notebooks/SEIR_01_1000_100_80_05_01_30_100_5_700step.csv', 'r')
#       2
# ----> 3 column_list = csv_file.readline().rstrip().split(',')
#       4
#       5 print(column_list)
#
# /usr/lib/python3.10/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 19-20: invalid continuation byte

# %%
recoad_list = []
recoad = csv_file.readline()
while recoad :
    recoad_list.append(recoad.rstrip().split(','))
    recoad = csv_file.readline()

# %%
# タブ区切りをjoin()で行い、表形式にして見やすくする。
print('\t'.join(column_list))
for recoad in recoad_list:
    print('\t\t'.join(recoad))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-f58bba86c2fa> in <cell line: 2>()
#       1 # タブ区切りをjoin()で行い、表形式にして見やすくする。
# ----> 2 print('\t'.join(column_list))
#       3 for recoad in recoad_list:
#       4     print('\t\t'.join(recoad))
#
# NameError: name 'column_list' is not defined

# %%
recoad_list[2]

# %%
recoad_list[0, 2]

# %% [markdown]
# ## csvインポートpandas

# %%
seir_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SEIR_01_1000_100_80_05_01_30_100_5_700step.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-16-0b1422db21d9> in <cell line: 1>()
# ----> 1 seir_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SEIR_01_1000_100_80_05_01_30_100_5_700step.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
seir_data.head()

# %%
seir_data.info()

# %%
seir_data['免疫保持者（除外者）の比率の最大値'].info

# %%
plt.hist(seir_data['免疫保持者（除外者）の比率の最大値'])
plt.xlabel('menekihoji')
plt.ylabel('menekihoji_max')
plt.grid(True)

# %%
# 平均値
print('平均値：', seir_data['免疫保持者（除外者）の比率の最大値'].mean())
# 中央値：中央値でデータを分けると中央値の前後でデータ数が同じになる（データの真ん中の値）、外れ値の値に影響を受けにくい
print('中央値：', seir_data['免疫保持者（除外者）の比率の最大値'].median())
# 最頻値：最も頻度が多い値
print('最頻値：', seir_data['免疫保持者（除外者）の比率の最大値'].mode())

# %%
plt.hist(seir_data['潜伏感染者（潜伏感受性者）の比率の最大値'])
plt.xlabel('menekihoji')
plt.ylabel('menekihoji_max')
plt.grid(True)

# %%
# 平均値
print('平均値：', seir_data['潜伏感染者（潜伏感受性者）の比率の最大値'].mean())
# 中央値：中央値でデータを分けると中央値の前後でデータ数が同じになる（データの真ん中の値）、外れ値の値に影響を受けにくい
print('中央値：', seir_data['潜伏感染者（潜伏感受性者）の比率の最大値'].median())
# 最頻値：最も頻度が多い値
print('最頻値：', seir_data['潜伏感染者（潜伏感受性者）の比率の最大値'].mode())

# %%
import numpy as np

# %%
# 以下のライブラリを使うので、あらかじめ読み込んでおいてください
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

# 可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# 小数第3位まで表示
# %precision 3

# %%
# 現在の値を表示
print('そのまま：', seir_data)

# ソートした結果を表示
# data = X.sort()
# print('ソート後：', data)

# %%
# 分散
seir_data['免疫保持者（除外者）の比率の最大値'].var()

# %%
seir_data['免疫保持者（除外者）の比率の最大値'].std()

# %%
np.sqrt(seir_data['免疫保持者（除外者）の比率の最大値'].var())

# %%
# 要約統計量
seir_data['免疫保持者（除外者）の比率の最大値'].describe()

# %% [markdown]
# #### 四方位範囲を求める
#
# `describe`メソッドの結果は、`Series`オブジェクトに入ります。
#
#
# それぞれの要素は、`describe()[インデックス番号]`として取得できます。たとえば、平均値を示す`mean`の値は、`describe()[1]`、標準偏差を示す`std`の値は`describe()[2]`です

# %%
# 四分位範囲(75%タイル ー 25%タイル)
seir_data['免疫保持者（除外者）の比率の最大値'].describe()[6] - seir_data['免疫保持者（除外者）の比率の最大値'].describe()[4]

# %%
# 箱ひげ図：G1,G2,G3
plt.boxplot([seir_data['免疫保持者（除外者）の比率の最大値'], seir_data['潜伏感染者（潜伏感受性者）の比率の最大値']])
plt.grid(True)

# %%
# 変動係数：免疫保持者（除外者）の比率の最大値
seir_data['免疫保持者（除外者）の比率の最大値'].std() / seir_data['免疫保持者（除外者）の比率の最大値'].mean()

# %%
# 変動係数：潜伏感染者（潜伏感受性者）の比率の最大値
seir_data['潜伏感染者（潜伏感受性者）の比率の最大値'].std() / seir_data['潜伏感染者（潜伏感受性者）の比率の最大値'].mean()

# %%
# それぞれの変動係数をまとめて計算
seir_data.std() / seir_data.mean()

# %%
# 散布図
plt.plot(seir_data['免疫保持者（除外者）の比率の最大値'], seir_data['潜伏感染者（潜伏感受性者）の比率の最大値'], 'o')# 長軸の長さと短軸の長さ

# ラベル
plt.ylabel('meneki_max')
plt.xlabel('senpuku_max')
plt.grid(True)

# %% [markdown]
# #### 共分散

# %%
# 共分散行列
np.cov(seir_data['免疫保持者（除外者）の比率の最大値'], seir_data['潜伏感染者（潜伏感受性者）の比率の最大値'])

# %% [markdown]
# 結果の行列の意味は、次の通りです。
#
# Major_Axis_LengthとMinor_Axis_Lengthの共分散 … 共分散行列の (1,2)
#  と (2,1)
#  の要素です。
#
# Major_Axis_Lengthの分散 … 共分散行列の (1,1)
#  の要素です。
#
# Minor_Axis_Lengthの分散 … 共分散行列の (2,2)
#  の要素です。
# それぞれMajor_Axis_LengthとMinor_Axis_Lengthの分散は、var関数で計算。実際に求めてみると、値が合致する。

# %%
# 分散
print('免疫保持者（除外者）の比率の最大値の分散:',seir_data['免疫保持者（除外者）の比率の最大値'].var())
print('潜伏感染者（潜伏感受性者）の比率の最大値の分散:',seir_data['潜伏感染者（潜伏感受性者）の比率の最大値'].var())

# %% [markdown]
# 相関係数

# %% [markdown]
# \begin{eqnarray}
# r_{xy} = \frac{\displaystyle \sum_{i = 1}^n (x_i - \overline{x})
# (y_i - \overline{y})}{\sqrt{\displaystyle \sum_{i = 1}^n
# (x_i - \overline{x})^2}\sqrt{\displaystyle \sum_{i = 1}^n
# (y_i - \overline{y})^2}}
# \end{eqnarray}

# %% [markdown]
# この相関係数は、-1から1までの値を取り、1に近ければ近いほど**正の相関**があるといい、-1に近ければ近いほど**負の相関**があるといいます。0に近い場合は、**無相関**であるといいます。

# %% [markdown]
# Pythonでは、ピアソン関数が計算できるScipyの`pearsonr`を使って、2変数の相関係数を算出できます。
#
# データ分析では 相関関数=ピアソン関数

# %%
sp.stats.pearsonr(seir_data['免疫保持者（除外者）の比率の最大値'], seir_data['潜伏感染者（潜伏感受性者）の比率の最大値'])

# %% [markdown]
# この相関係数は、-1から1までの値を取り、1に近ければ近いほど**正の相関**があるといい、-1に近ければ近いほど**負の相関**があるといいます。0に近い場合は、**無相関**であるといいます。

# %%
# 相関行列
np.corrcoef([seir_data['免疫保持者（除外者）の比率の最大値'], seir_data['潜伏感染者（潜伏感受性者）の比率の最大値']])

# %%
import seaborn as sn

# %%
sn.pairplot(seir_data[['健常者（感受性者）の比率の最大値', '(実行が始まってから)健常者（感受性者）の比率の最小値', '免疫保持者（除外者）の比率の最大値', '潜伏感染者（潜伏感受性者）の比率の最大値']])
plt.grid(True)

# %%
# 例：面積ごとの長軸の平均値
seir_data.groupby('感染者の比率の最大値')['潜伏感染者（潜伏感受性者）の比率の最大値'].mean()

# %%
rice.groupby(rice['Area']==8499)['Major_Axis_Length'].mean()

# %%
rice_cammeo_and_osmancik

# %%
y

# %%
# 例：面積ごとの長軸の平均値
rice.groupby(y['Class']=='Cammeo')['感染者の比率の最大値'].mean()

# %%
print('そのまま：', rice)

# %% [markdown]
# #### 練習問題

# %% [markdown]
# #### 3.4単回帰分析

# %%
# 散布図
plt.plot(rice['Major_Axis_Length'], rice['Minor_Axis_Length'], 'o')
plt.xlabel('長軸の長さ')
plt.ylabel('短軸の長さ')
plt.grid(True)

# %%
from sklearn import linear_model

# 線形回帰のインスタンスを生成
reg = linear_model.LinearRegression()

# %% [markdown]
# 以下では、説明変数（$X$とします）と目的変数（$Y$とします）データをセットして、線形回帰する`fit`という機能を使って、予測モデルを計算します。
#
# この場合の`fit`関数は、**最小二乗法**という手法で回帰係数$a$と切片$b$を計算しています。この方法は、実際の目的変数のデータと予測したデータの差の二乗和をとり、それが最小になる時の係数と切片を求めるものです。式で表現すると、$y$を実測値、$ f(x) = ax + b $を予測値として、以下の式を最小にするように計算しています（計算方法としては、この式を微分していくのですが、`fit`関数を実行すれば、その計算をしてくれるので詳細は割愛します）。

# %% [markdown]
# \begin{eqnarray}
# \sum^n_{i=1}(y_i-f(x_i))^2
# \end{eqnarray}

# %%
# 説明変数に "長軸の長さ" を利用
# locはデータフレームから、行と列を指定して取り出す。loc[:, ['G1']]は、G1列のすべての列を取り出すことをしている
# valuesに直しているので、注意
X = seir_data.loc[:, ['感染者の比率の最大値']].values

# 目的変数に "短軸の長さ" を利用
Y = seir_data['感染者の比率の最小値'].values

# 予測モデルを計算、ここでa,bを算出
reg.fit(X, Y)

# 回帰係数
print('回帰係数:', reg.coef_)

# 切片
print('切片:', reg.intercept_)

# %% [markdown]
# 上記の回帰係数が線形の回帰式 $ y = ax + b $ における$ a $に相当し、切片に相当するのが$b$です。先ほどの散布図と重ねて、予測した線形回帰式を描いてみましょう。$Y$、つまり予測したい最終の数学の成績G3は、`predict`を使って、括弧の中に説明変数を入れることで計算できます。

# %%
# 先ほどと同じ散布図
plt.scatter(X, Y)
plt.xlabel('感染者の比率の最大値')
plt.ylabel('感染者の比率の最小値')

# その上に線形回帰直線を引く
plt.plot(X, reg.predict(X))
plt.grid(True)

# %% [markdown]
# ### 3.4.2 決定係数
#
# 上記のグラフ + 客観的にどうなのかを数値化したものが、**決定係数**
# 決定係数は寄与率とも呼ばれます。定義は以下のとおりです。決定係数は$R^2$と示すことが一般的です。

# %% [markdown]
# \begin{eqnarray}
# R^2 = 1 - \frac{\sum_{i = 1}^n(y_i - f(x_i))^2}{\sum_{i = 1}^{n}(y_i - \bar{y})^2}
# \end{eqnarray}

# %% [markdown]
# $R^2$は最大で1の値を取り、1に近ければ近いほど良いモデルになります。$\bar{y}$は目的変数の平均値です。説明変数を使わずに常に$\bar{y}$（定数）で予測した場合と二乗誤差が等しい場合に $R^2=0$ となります。Pythonを使って決定係数を求めるには、`score`を使って以下のようにします。

# %%
# 決定係数、寄与率とも呼ばれる
print('決定係数:', reg.score(X, Y))

# %% [markdown]
# # SEIR 2023/10/11

# %%
from numpy import random

# 以下のライブラリを使うので、あらかじめ読み込んでおいてください
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

# 可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# 小数第3位まで表示
# %precision 3
# Out:
# '%.3f'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
heartdisease_cleveland_data2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SEIR_01_3000_100_10_1_01_30_100_5_700step.csv', sep=',', encoding='Shift-JIS')

# %%
heartdisease_cleveland_data2#.readline().rstrip().split(b',')
# Out:
#                          譛蠕(9逡ｪ逶ｮ)縺ｫ1縺0縺九▽縺代ｋ,,,,,,,,
# 0   0.966,0.37066666666666664,0.4093333333333333,0...
# 1   0.995,0.0036666666666666666,0,0,0.001333333333...
# 2   0.9956666666666667,0.0033333333333333335,0,0.0...
# 3   0.996666667,0.003333333,0,0,0.996666667,0.0033...
# 4   0.994333333,0.003666667,0,0.002,0.994333333,0....
# 5   0.995666667,0.003666667,0,0.000666666,0.995666...
# 6   0.995666667,0.003666667,0,0.000666666,0.995666...
# 7   0.995666667,0.003666667,0,0.000666666,0.995666...
# 8   0.995666667,0.003666667,0,0.000666666,0.995666...
# 9   0.995666667,0.366333333,0.399666667,0.14666666...
# 10  0.995,0.003666667,0,0.001333333,0.995,0.003666...
# 11  0.996333333,0.003333333,0,0.000333333,0.996333...
# 12  0.996333333,0.376,0.398,0.151,0.186666667,0.37...
# 13  0.996333333,0.003333333,0,0.000333333,0.996333...
# 14                      0.99,0.01,0,0,0.99,0.01,0,0,0
# 15  0.995333333,0.003666667,0,0.001,0.995333333,0....
# ...

# %%
from pathlib import Path

read_path = Path('/content/drive/MyDrive/Colab Notebooks/SEIR_01_3000_100_10_1_01_30_100_5_700step.csv')

# 読み込み
content = read_path.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-4a9e8a300a7f> in <cell line: 6>()
#       4
#       5 # 読み込み
# ----> 6 content = read_path.read()
#
# AttributeError: 'PosixPath' object has no attribute 'read'

# %%
csv_file = open('/content/drive/MyDrive/Colab Notebooks/SEIR_01_3000_100_10_1_01_30_100_5_700step.csv', 'rb')

column_list = csv_file.readline().rstrip().split(b',')

print(column_list)
# Out:
# [b'"\xe6\x9c\xe5\xbe(9\xe7\x95\xaa\xe7\x9b\xae)\xe3\x81\xab1\xe3\x810\xe3\x81\x8b\xe3\x81\xa4\xe3\x81\x91\xe3\x82\x8b', b'', b'', b'', b'', b'', b'', b'', b'"']

# %%
with open('/content/drive/MyDrive/Colab Notebooks/SEIR_01_3000_100_10_1_01_30_100_5_700step.csv', 'rb') as file:
  content = file.read()
  # バイトデータを操作、修正
  decoded_content = content.decode('utf-8', errors='replace')
  # エンコードの問題を修正してからデコード
  df = pd.read_csv(pd.compat.StringIO(decoded_content))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-b9227c7126b2> in <cell line: 1>()
#       4   decoded_content = content.decode('utf-8', errors='replace')
#       5   # エンコードの問題を修正してからデコード
# ----> 6   df = pd.read_csv(pd.compat.StringIO(decoded_content))
#
# AttributeError: module 'pandas.compat' has no attribute 'StringIO'

# %%
l_part1 = []

# %%
recoad_list = []
recoad = csv_file.readline()
while recoad:
    recoad_list.append(recoad.rstrip().split(b','))
    recoad = csv_file.readline()

# %%
# タブ区切りをjoin()で行い、表形式にして見やすくする。
print(b'\t\t'.join(column_list))
for recoad in recoad_list:
    print(b'\t\t'.join(recoad))
# Out:
# b'"\xe6\x9c\xe5\xbe(9\xe7\x95\xaa\xe7\x9b\xae)\xe3\x81\xab1\xe3\x810\xe3\x81\x8b\xe3\x81\xa4\xe3\x81\x91\xe3\x82\x8b\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t"'
# b'"0.966\t\t0.37066666666666664\t\t0.4093333333333333\t\t0.14366666666666666\t\t0.19\t\t0.266666666666668\t\t0.37066666666666664\t\t0.4093333333333333\t\t0.1466666666666666\t\t1"'
# b'"0.995\t\t0.0036666666666666666\t\t0\t\t0\t\t0.0013333333333333333\t\t0.995\t\t0.003\t\t0.0036666666666666666\t\t0\t\t0.0013333333333333333\t\t0"'
# b'"0.9956666666666667\t\t0.0033333333333333335\t\t0\t\t0.001\t\t0.9956666666666667\t\t0.0033333333333333335\t\t0\t\t0.001\t\t0"'
# b'"0.996666667\t\t0.003333333\t\t0\t\t0\t\t0.996666667\t\t0.003333333\t\t0\t\t0\t\t0"'
# b'"0.994333333\t\t0.003666667\t\t0\t\t0.002\t\t0.994333333\t\t0.003666667\t\t0\t\t0.002\t\t0"'
# b'"0.995666667\t\t0.003666667\t\t0\t\t0.000666666\t\t0.995666667\t\t0.003666667\t\t0\t\t0.000666667\t\t0"'
# ...

# %%
import requests, zipfile
from io import StringIO
import io

from numpy import random

# 以下のライブラリを使うので、あらかじめ読み込んでおいてください
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

# 可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()

# %%
data_heart_disease = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SEIR_01_3000_100_10_1_01_30_100_5_700step.csv', encoding="Shift-JIS")

# %%
data_heart_disease
# Out:
#                          譛蠕(9逡ｪ逶ｮ)縺ｫ1縺0縺九▽縺代ｋ,,,,,,,,
# 0   0.966,0.37066666666666664,0.4093333333333333,0...
# 1   0.995,0.0036666666666666666,0,0,0.001333333333...
# 2   0.9956666666666667,0.0033333333333333335,0,0.0...
# 3   0.996666667,0.003333333,0,0,0.996666667,0.0033...
# 4   0.994333333,0.003666667,0,0.002,0.994333333,0....
# 5   0.995666667,0.003666667,0,0.000666666,0.995666...
# 6   0.995666667,0.003666667,0,0.000666666,0.995666...
# 7   0.995666667,0.003666667,0,0.000666666,0.995666...
# 8   0.995666667,0.003666667,0,0.000666666,0.995666...
# 9   0.995666667,0.366333333,0.399666667,0.14666666...
# 10  0.995,0.003666667,0,0.001333333,0.995,0.003666...
# 11  0.996333333,0.003333333,0,0.000333333,0.996333...
# 12  0.996333333,0.376,0.398,0.151,0.186666667,0.37...
# 13  0.996333333,0.003333333,0,0.000333333,0.996333...
# 14                      0.99,0.01,0,0,0.99,0.01,0,0,0
# 15  0.995333333,0.003666667,0,0.001,0.995333333,0....
# ...
