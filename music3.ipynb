# %% [markdown]
# # コード進行

# %% [markdown]
# ## jpop コード進行

# %% [markdown]
# F ⇒ G ⇒ Em ⇒ Am
#
# F ⇒ C ⇒ G ⇒ Am
#
# F ⇒ G ⇒ E ⇒ Am
#
# Am ⇒ F ⇒ G ⇒ C
#
# Am ⇒ Em ⇒ F ⇒ G
#
# F ⇒ G ⇒ Am ⇒ Em
#
# C/E ⇒ F ⇒ G ⇒ Am
#
# Am ⇒ G ⇒ F ⇒ C
#
# Dm ⇒ Em ⇒ F ⇒ G
#
# F ⇒ E7 ⇒ Am ⇒ C
#
# C ⇒ G ⇒ F ⇒ C
#
# C ⇒ F ⇒ G ⇒ C

# %%
jpop_popular_code = [
  ["Dm","Em","F","G"],
  ["F","E7","Am","C"]
  ["C","G","F","C"],
  ["C","F","G","C"]
]

# %% [markdown]
# ## 曲名: 君はロックを聞かない

# %%
intro_kimiharokkuwokikanai_1 = [
    [["C","",1],["D","",1],["B","m7",1],["E","m",1]],
    [["A","m7",1],["B","",1],["E","m",2]]
]
intro_kimiharokkuwokikanai_2 = [
    [["C","",1],["D","",1],["B","m7",1],["E","m",1]],
    [["A","m7",2],["D","",2]]
]
kimiwarokkuwokikanai_1 = [
    [["G","",2],["D","",2]],
    [["C","",1],["D","",1],["G","",2]],
    [["C","",1],["D","",1],["B","m",1],["E","m",1]],
    [["C","",2],["D","",2]]
]
kimiwarokkuwokikanai_2 = [
    [["G","",2],["D","",2]],
    [["C","",1],["D","",1],["G","",2]],
    [["C","",1],["D","",1],["B","m",1],["E","m",1]],
    [["C","",1],["D","",1],["G","",2]]
]
kimiwarokkuwokikanai_3 = [
    [["C","",1],["D","",1],["B","m",1],["E","m",1]],
    [["C","",2],["D","",2]]
]
sabi_1 = [
    [["C","",1],["D","",1],["B","m",1],["E","m",1]],
    [["C","",1],["D","",1],["D#","dim",1],["E","m",1]],
    [["C","",1],["D","",1],["G","",0.5],["F#","",0.5],["E","",1]],
    [["C","",1],["G","",2]],
    [["C","",1],["D","",1],["G","",0.5]]
]
kansou_2 = [
    [["C","",1],["D","",1],["B","m7",1],["E","m",1]],
    [["C","",1],["D","",1],["B","m7",1],["E","m",1]],
    [["C","",1],["D","",1],["B","m7",1],["E","m",1]]
    [["C","",1],["D","",1]]
]
